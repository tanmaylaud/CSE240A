------------------------------------
9 8 8
------------------------------------
int 1
Branches:           3771697
Incorrect:           612647
Misprediction Rate:  16.243
int 2
Branches:           3755315
Incorrect:            19697
Misprediction Rate:   0.525
mm 1
Branches:           3014850
Incorrect:           221616
Misprediction Rate:   7.351
mm 2
Branches:           2563897
Incorrect:           273568
Misprediction Rate:  10.670
fp 1
Branches:           1546797
Incorrect:            15404
Misprediction Rate:   0.996
fp 2
Branches:           2422049
Incorrect:            83628
Misprediction Rate:   3.453
------------------------------------
9 10 10
------------------------------------
int 1
Branches:           3771697
Incorrect:           476073
Misprediction Rate:  12.622
int 2
Branches:           3755315
Incorrect:            15980
Misprediction Rate:   0.426
mm 1
Branches:           3014850
Incorrect:            77802
Misprediction Rate:   2.581
mm 2
Branches:           2563897
Incorrect:           217501
Misprediction Rate:   8.483
fp 1
Branches:           1546797
Incorrect:            15329
Misprediction Rate:   0.991
fp 2
Branches:           2422049
Incorrect:            78619
Misprediction Rate:   3.246
"""

# %%
result_list = result.split('\n')
misprediction = {}
for i in range(0,27*14,27):
    r = result_list[i:i+27]
    mis = []
    for line in r:
        if 'Mis' in line:
            mis.append(float(line.replace('Misprediction Rate:  ','')))
    print(r[0])
    r[0] = r[0].replace(' ',':')
    misprediction[r[0]] = {
        'int_1': mis[0],
        'int_2': mis[1],
        'mm_1': mis[2],
        'mm_2': mis[3],
        'fp_1': mis[4],
        'fp_2': mis[5]
    }
# Out:
# 1 2 1
# 1 2 2
# 1 3 3
# 2 2 2
# 3 1 2
# 3 3 3
# 4 2 1
# 4 3 3
# 4 4 4
# 5 3 1
# 6 4 1
# 7 8 8
# 9 8 8
# 9 10 10

# %%
pd.DataFrame(misprediction).T
# Out:
#           int_1  int_2    mm_1    mm_2   fp_1    fp_2
# 1:2:1    31.677  1.556  50.216  28.181  3.585  32.024
# 1:2:2    33.376  1.595  46.562  27.844  3.411  30.013
# 1:3:3    32.680  1.470  44.612  25.514  3.456  22.583
# 2:2:2    32.426  1.559  41.955  26.402  3.240  27.724
# 3:1:2    31.844  1.573  41.022  25.529  2.858  31.453
# 3:3:3    31.946  1.401  41.509  23.869  2.654  21.292
# 4:2:1    30.970  1.461  37.551  23.696  2.762  22.571
# 4:3:3    31.579  1.366  37.840  22.502  2.624  18.267
# 4:4:4    30.586  1.399  31.074  21.386  2.118  15.983
# 5:3:1    30.510  1.327  29.464  21.397  2.454  19.744
# 6:4:1    28.549  1.254  25.940  19.800  2.207  11.145
# 7:8:8    19.264  0.584  10.930  11.879  0.997   4.008
# 9:8:8    16.243  0.525   7.351  10.670  0.996   3.453
# 9:10:10  12.622  0.426   2.581   8.483  0.991   3.246

# %%
pd.DataFrame(misprediction).T.plot()
plt.xticks(range(14),pd.DataFrame(misprediction).T.index,rotation=45)
plt.xlabel('GlobalH_Bits : LocalH_Bits : PC_Bits ')
plt.ylabel('Misprediction Rate')
# Out:
# Text(0, 0.5, 'Misprediction Rate')
